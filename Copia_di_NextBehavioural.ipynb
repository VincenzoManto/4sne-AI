# %% [markdown]
# <a href="https://colab.research.google.com/github/VincenzoManto/4sne-AI/blob/main/Copia_di_NextBehavioural.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow>=2.4.0 flask flask-socketio
# !pip install tensorflow-addons
# !pip install transformers
# !pip install tensorflow_text
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.11/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (24.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.47.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: tensorflow_text in /usr/local/lib/python3.11/dist-packages (2.18.1)
# Requirement already satisfied: tensorflow<2.19,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_text) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (25.1.21)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (1.69.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (3.5.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18.0->tensorflow_text) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow<2.19,>=2.18.0->tensorflow_text) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18.0->tensorflow_text) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18.0->tensorflow_text) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18.0->tensorflow_text) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18.0->tensorflow_text) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18.0->tensorflow_text) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18.0->tensorflow_text) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18.0->tensorflow_text) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18.0->tensorflow_text) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18.0->tensorflow_text) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18.0->tensorflow_text) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18.0->tensorflow_text) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow<2.19,>=2.18.0->tensorflow_text) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow<2.19,>=2.18.0->tensorflow_text) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.19,>=2.18.0->tensorflow_text) (0.1.2)

# %%
import requests
import json
response = requests.post('https://lelli-kelly.lellikelly.it/SysDat.Stark.WebAPI/api/account/token', data=json.dumps({"username":"SUPERVISOR","password":"Password99!","force":False,"client":"MTY3OTMwNzM0ODMyMQ=="}), headers={"Content-Type": "application/json"})
print(response.json())
token = response.json()['token']
# Out:
# {'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..mkNrvsYKrCA28STN2AT8fNKPEM65YAzXHFen4g3kxbo'}

# %%
def get_dati():
    import re
    response = requests.post('https://lelli-kelly.lellikelly.it/SysDat.Stark.WebAPI/api/MonitorGDPR/search',
                             data=json.dumps({
          "take": 57500,
          "filter": {

          },
          "skip": 0,
          "sortBy": "Apertura",
          "sortDir": "desc",
          "OrderBy": []
      }),
    headers={"Authorization": "Bearer " + token, "Company-Key": "LELLIKELLY", "Content-Type": "application/json"})
    result = response.json()['Results'][::-1]
    result = list(map(lambda x: {"PageName": x["PageName"], "UserName": x["UserName"], "Apertura": x["Apertura"]}, result))
    # Collassa azioni duplicate
    dati_collassati = [result[0]]
    for azione in result[1:]:
        azione["PageName"] = re.sub(r'/\d+/*', "/:n/", azione["PageName"])
        #azione["PageName"] = re.sub(r'/(\d+|new)/*.*', "", azione["PageName"])
        if azione["UserName"] == dati_collassati[-1]["UserName"] and azione["PageName"] == dati_collassati[-1]["PageName"]:
            continue  # Azione duplicata, ignoralo
        dati_collassati.append(azione)
    return dati_collassati
dati = get_dati()

# %%
import pandas as pd
df = pd.DataFrame(dati)
print(df.Apertura.min())
df.describe()
# Out:
# 2024-12-16T08:47:04
#                 PageName UserName             Apertura
# count              45332    45332                45332
# unique               422       20                43951
# top     /customer-orders  ELISABA  2025-01-23T11:16:52
# freq                5958     8762                    3

# %% [markdown]
# # Analisi dati
#
# Prima di iniziare, verifichiamo come sono distribuiti i dati, sia nel tempo che tra utenti

# %%
from matplotlib import pyplot as plt
df["Apertura"] = pd.to_datetime(df["Apertura"])

print("Statistiche generali:")
print(df.describe(include='all'))

page_distribution = df["PageName"].value_counts()
print("\nDistribuzione per PageName:")
print(page_distribution)

user_distribution = df["UserName"].value_counts()
print("\nDistribuzione per UserName:")
print(user_distribution)

activity_over_time = df.set_index("Apertura").resample("D").size()

plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 2)
activity_over_time.plot()
plt.title("Attività nel tempo")
plt.xlabel("Data")
plt.ylabel("Conteggio azioni")

plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 4))
user_distribution.plot(kind="bar")
plt.title("Distribuzione degli utenti")
plt.xlabel("UserName")
plt.ylabel("Conteggio")
plt.xticks(rotation=45)
plt.show()
# Out:
# Statistiche generali:
#                 PageName UserName                       Apertura
# count              45332    45332                          45332
# unique               422       20                            NaN
# top     /customer-orders  ELISABA                            NaN
# freq                5958     8762                            NaN
# mean                 NaN      NaN  2025-01-12 03:25:53.382710016
# min                  NaN      NaN            2024-12-16 08:47:04
# 25%                  NaN      NaN     2025-01-07 14:21:27.500000
# 50%                  NaN      NaN            2025-01-15 13:16:51
# 75%                  NaN      NaN            2025-01-22 11:00:49
# max                  NaN      NaN            2025-01-28 17:44:29
#
# Distribuzione per PageName:
# PageName
# /customer-orders                                            5958
# /customer-orders/:n/general-data                            4913
# /accounting/customer-document-header                        2340
# /                                                           2335
# /business-partners/customers                                1967
#                                                             ...
# /products/copy/:n/general-data/modal/lines/new                 1
# /general-data/zones/:n/                                        1
# /general-data/categories/:n/                                   1
# /customer-orders/assignment-to-sales-order?nordine=13837       1
# /general-data/price-lists/new                                  1
# Name: count, Length: 422, dtype: int64
#
# Distribuzione per UserName:
# UserName
# ELISABA        8762
# ANDREADA       5197
# MARTINAGI      4140
# ANTONIOME      3824
# ANDREARA       2785
# BRUNELLANA     2620
# MAGAZZINO02    2470
# EMMAPL         2372
# CRISTINABE     2101
# ANTONIOAT      2048
# SUPERVISOR     2014
# FEDERICACE     1890
# ALBADE         1110
# CHIARAPE       1037
# FEDERICAC      1013
# MAGAZZINO01     587
# SIMONAST        506
# ELEONORARI      420
# LUCIACA         304
# FRANCESCANA     132
# Name: count, dtype: int64

# %% [markdown]
# ## Dati per data ed utente

# %%
import pandas as pd
import matplotlib.pyplot as plt

df["Apertura"] = pd.to_datetime(df["Apertura"])

# raggruppo le attività per UserName e data
activity_per_user = df.groupby(["UserName", pd.Grouper(key="Apertura", freq="D")]).size().unstack(fill_value=0)

min_date = activity_per_user.columns.min()
max_date = activity_per_user.columns.max()


num_users = len(activity_per_user)
cols = 2
rows = (num_users + cols - 1) // cols

# Crea la figura e gli assi
fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 4), sharex=True)
axes = axes.flatten()

# un grafico per ciascun utente
for i, user in enumerate(activity_per_user.index):
    ax = axes[i]
    user_data = activity_per_user.loc[user]
    ax.bar(user_data.index, user_data.values)
    ax.set_xlim([min_date, max_date])
    ax.set_ylim([0, user_data.max()])
    total_actions = user_data.sum()
    ax.set_title(f"Attività per {user} (Totale: {total_actions})")
    ax.set_xlabel("Data")
    ax.set_ylabel("Conteggio azioni")


for j in range(num_users, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analisi coppie consecutive
#
# Per ogni record log, **raggruppato per utente (!)**, abbino una nuova colonna `NextPage` che è il `PageName` del record log successivo di quell'utente.
#
# > ! Attenzione
# >
# > Questa operazione concatena come azioni consecutive anche cambi di pagina intragiornalieri, ovvero un'azione eseguita alle 18:00 verrà considerata insieme all'azione successiva eseguita alle 09:00
#
# Giocare con la `soglia_azioni` per vedere più meno o righe

# %%
import seaborn as sns
soglia_azioni = 250

# Ordino i dati per Utente e Timestamp
df_pair = df.sort_values(by=["UserName", "Apertura"])
df_pair = df_pair[df_pair['PageName'] != '/']

# Genero le coppie di transizioni consecutive
df_pair["NextPage"] = df_pair.groupby("UserName")["PageName"].shift(-1)
transitions = df_pair.dropna(subset=["NextPage"])

# Conteggio delle transizioni
transition_counts = transitions.groupby(["PageName", "NextPage"]).size().reset_index(name="Count")

# Filtra le transizioni con conteggio superiore a soglia_azioni
filtered_transitions = transition_counts[transition_counts["Count"] > soglia_azioni]
print(filtered_transitions.shape)
# Out:
# (24, 3)

# %% [markdown]
# ### Istogramma delle coppie consecutive

# %%
# filtered_transitions = filtered_transitions[filtered_transitions["Count"] < 3500]
# Istogramma delle coppie di transizioni
plt.figure(figsize=(10, 6))
filtered_transitions_sorted = filtered_transitions.sort_values(by="Count", ascending=False)
plt.bar(
    [f"({a},{b})" for a, b in zip(filtered_transitions_sorted["PageName"], filtered_transitions_sorted["NextPage"])],
    filtered_transitions_sorted["Count"]
)
plt.title(f"Distribuzione delle coppie di transizioni consecutive (Count > {soglia_azioni})")
plt.xlabel("Coppia di pagine")
plt.ylabel("Frequenza")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-30-e838d297a87e>:13: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### Matrice di transizione
#
# Questa matrice associa le N pagine più comuni (estratte precedentemente in funzione di `soglia_azioni`) e le incrocia con sé stesse (altre N pagine) creando una matrice ***simmetrica*** NxN
#
# Leggendo una riga, ogni cella rappresenterà la probabilità che, data la pagina intestazione della riga, la prossima pagina sia l'azione intestazione della colonna

# %%
# matrice di transizione
filtered_transition_matrix = pd.pivot_table(
    filtered_transitions,
    values="Count",
    index="PageName",
    columns="NextPage",
    fill_value=0
)

# visualizzazione
plt.figure(figsize=(12, 8))
plt.imshow(filtered_transition_matrix, aspect="auto", cmap="Blues")
plt.colorbar(label="Frequenza")
plt.xticks(range(len(filtered_transition_matrix.columns)), filtered_transition_matrix.columns, rotation=90)
plt.yticks(range(len(filtered_transition_matrix.index)), filtered_transition_matrix.index)
plt.title(f"Matrice di transizione delle pagine (Count > {soglia_azioni})")
plt.xlabel("Pagina Successiva")
plt.ylabel("Pagina Precedente")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Predizione
#
# Data la struttura della matrice, usarla per prevedere la next action. La funzione userà la matrice `filtered_transition_matrix` e richiederà in input solo la pagina attuale.
#
# Questo tipo di predizione è quindi basata solo sulle relazioni tra pagine ed ignora sia l'operatore che visita la pagina, sia quando l'azione viene compiuta

# %%
import numpy as np
def predict_next_action(pageName):
  # argmax della matrice di transizione filtrata per pageName
  filtered_transition_matrix2 = filtered_transition_matrix.loc[pageName]
  return np.argmax(filtered_transition_matrix2.values)

for i, row in filtered_transition_matrix.iterrows():
  exp =   predict_next_action(i)
  print(f"Pagina Corrente: {i}, Pagina Successiva: {filtered_transition_matrix.columns[exp]}")
# Out:
# Pagina Corrente: /accounting/customer-document-header, Pagina Successiva: /accounting/customer-document-header/:n/general-data
# Pagina Corrente: /accounting/customer-document-header/:n/general-data, Pagina Successiva: /accounting/customer-document-header
# Pagina Corrente: /business-partners/customers, Pagina Successiva: /business-partners/customers/:n/general-data
# Pagina Corrente: /business-partners/customers/:n/general-data, Pagina Successiva: /business-partners/customers
# Pagina Corrente: /business-partners/customers/:n/management-data/settings, Pagina Successiva: /business-partners/customers
# Pagina Corrente: /customer-orders, Pagina Successiva: /customer-orders/:n/general-data
# Pagina Corrente: /customer-orders/:n/general-data, Pagina Successiva: /customer-orders
# Pagina Corrente: /customer-orders/packing-list-management/:n/, Pagina Successiva: /customer-orders/pick-list-situation
# Pagina Corrente: /customer-orders/pick-list-situation, Pagina Successiva: /customer-orders/packing-list-management/:n/
# Pagina Corrente: /price-lists, Pagina Successiva: /price-lists/:n/
# Pagina Corrente: /price-lists/:n/, Pagina Successiva: /price-lists
# Pagina Corrente: /price-lists/copy/:n/, Pagina Successiva: /price-lists
# Pagina Corrente: /products, Pagina Successiva: /products/:n/general-data
# Pagina Corrente: /products/:n/enablings/drops, Pagina Successiva: /products/:n/sale-pairings-v2
# Pagina Corrente: /products/:n/enablings/variants, Pagina Successiva: /products/:n/enablings/drops
# Pagina Corrente: /products/:n/general-data, Pagina Successiva: /products
# Pagina Corrente: /products/:n/sale-pairings-v2, Pagina Successiva: /products
# Pagina Corrente: /products/copy/:n/images, Pagina Successiva: /products
# Pagina Corrente: /products/copy/:n/sale-pairings-v2, Pagina Successiva: /products/copy/:n/images
# Pagina Corrente: /warehouses/warehouse-management/views-and-selection, Pagina Successiva: /warehouses/warehouse-management/movements-research

# %% [markdown]
# ## Calcolo dell'accuracy per la baseline statistica
#
# Testiamo l'efficacia di questo modello usando come testset il nostro intero dataset e vedendo se questo approccio predice coerentemente alla **ground truth** (errata concettualente), ovvero `NextPage`

# %%
sum = 0
for i, row in filtered_transitions.iterrows():
  #print(row)
  predicted = predict_next_action(row['PageName'])
  print(predicted)
  truth = row['NextPage']
  if (predicted == truth):
    sum = sum + 1


accuracy = sum / len(df_pair)
print(sum)
# Out:
# 1
# 1
# 0
# 4
# 3
# 3
# 3
# 7
# 6
# 9
# 8
# 11
# 10
# 10
# 14
# 14
# 15
# 13
# 12
# 12
# 12
# 12
# 17
# 18
# 0

# %% [markdown]
# # FINE - IGNORARE OLTRE
#
# QUESTO SARA' IL SECONDO STEP LSTM

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
df_train = df[df['PageName'] != '/'].copy()

df_train['Apertura'] = pd.to_datetime(df_train['Apertura'])

df_train['DayOfWeek'] = df_train['Apertura'].dt.dayofweek
df_train['HourOfDay'] = df_train['Apertura'].dt.hour

# label_encoder_user = LabelEncoder()
# label_encoder_page = LabelEncoder()

# df_train['UserName'] = label_encoder_user.fit_transform(df_train['UserName'])
# df_train['PageName'] = label_encoder_page.fit_transform(df_train['PageName'])
df_train['NextPage'] = df_train['PageName'].shift(-1)

# min_threshold = 20
# class_counts = df_train['NextPage'].value_counts()
# rare_classes = class_counts[class_counts < min_threshold].index

# for c in rare_classes:
#   print(f'Pagina #{int(c)} {label_encoder_page.inverse_transform([int(c)])[0]}')

# # rimuovere rare_classes--> si può fare più semplicemente?
# df_train['NextPage'] = df_train['NextPage'].apply(lambda x: -1.0 if x in rare_classes else x)
# df_train = df_train[df_train['NextPage'] > -1]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Concatenate, Flatten

df_for_model = df_train.copy()
# print(df_for_model.head())
categorical_cols = ['UserName']# ['UserName' ]
numerical_cols = [] # ['DayOfWeek', 'HourOfDay']
sequence_col = 'PageName'
target_col = 'NextPage'

# Encoding per le variabili categoriche
sequence_encoding = LabelEncoder()
sequence_encoding.fit(list(df_for_model[sequence_col].values) + list(df_for_model[target_col].values))
df_for_model[sequence_col] = sequence_encoding.transform(df_for_model[sequence_col])
df_for_model[target_col] = sequence_encoding.transform(df_for_model[target_col])

print(f'Encoding della pagina, nr di classi: {len(sequence_encoding.classes_)}')


encoders = {col: LabelEncoder() for col in categorical_cols}
for col in categorical_cols:
    df_for_model[col] = encoders[col].fit_transform(df_for_model[col])

if numerical_cols:
  # Normalizzazione delle variabili numeriche
  scaler = StandardScaler()
  df_for_model[numerical_cols] = scaler.fit_transform(df_for_model[numerical_cols])

# print(df_for_model.head())

X_pages = []
X_categoricals = {col: [] for col in categorical_cols}
X_numericals = []
y = []

sequence_length = 1

from tqdm import tqdm
for i in tqdm(range(len(df_for_model) - sequence_length)):
    # Sequenza per PageName
    seq_pages = df_for_model[sequence_col].iloc[i:i+sequence_length].values
    X_pages.append(seq_pages)

    # Sequenze per variabili categoriche
    for col in categorical_cols:
        seq_cat = df_for_model[col].iloc[i:i+sequence_length].values
        X_categoricals[col].append(seq_cat)

    # Sequenze per variabili numeriche
    seq_num = df_for_model[numerical_cols].iloc[i:i+sequence_length].mean(axis=0).values
    X_numericals.append(seq_num)

    # Target
    target = df_for_model[target_col].iloc[i+sequence_length]
    y.append(target)

###################################
# Dimensioni Modello
vocab_size = len(sequence_encoding.classes_)
embedding_dim = 32
lstm_units = 128
#########
# Input sequenza di pagine
page_input = Input(shape=(sequence_length,), name="Page_Input")
page_embedding = Embedding(input_dim=vocab_size, output_dim=embedding_dim, name="Page_Embedding")(page_input)
lstm_output = LSTM(units=lstm_units, name="LSTM")(page_embedding)

# Input variabili categoriche
categorical_inputs = []
categorical_embeddings = []
for col in categorical_cols:
    vocab_size_cat = df[col].nunique()
    cat_input = Input(shape=(sequence_length,), name=f"{col}_Input")
    cat_embedding = Embedding(input_dim=vocab_size_cat, output_dim=10, name=f"{col}_Embedding")(cat_input)
    cat_embedding_flat = Flatten(name=f"{col}_Flatten")(cat_embedding)
    categorical_inputs.append(cat_input)
    categorical_embeddings.append(cat_embedding_flat)

# Input variabili numeriche
numerical_input = Input(shape=(len(numerical_cols),), name="Numerical_Input")

# Concatenazione
merged = Concatenate(name="Concatenate")([lstm_output] + categorical_embeddings + [numerical_input])

# Output layer
output = Dense(units=vocab_size, activation='softmax', name="Output")(merged)

# Modello
model = Model(inputs=[page_input] + categorical_inputs + [numerical_input], outputs=output)
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"])
model.summary()


X_pages = np.array(X_pages)
X_categoricals = {col: np.array(seqs) for col, seqs in X_categoricals.items()}
X_numericals = np.array(X_numericals)

# split del modello

from sklearn.model_selection import train_test_split

# Sequenze di input
X_pages = np.array(X_pages)
X_categoricals = {col: np.array(seqs) for col, seqs in X_categoricals.items()}
X_numericals = np.array(X_numericals)

# Target
y = np.array(y)

indices = np.arange(len(X_pages))

# Split per le sequenze principali (PageName)
X_pages_train, X_pages_test, y_train, y_test, train_idx, test_idx = train_test_split(
    X_pages, y, indices, test_size=0.2, random_state=42
)

# Split per le variabili categoriche
X_categoricals_train = {}
X_categoricals_test = {}
for col in X_categoricals:
  X_categoricals_train[col] = X_categoricals[col][train_idx,:]
  X_categoricals_test[col] = X_categoricals[col][test_idx,:]

# Split per le variabili numeriche
X_numericals_train = X_numericals[train_idx,:]
X_numericals_test = X_numericals[test_idx,:]


# Addestra il modello
history = model.fit(
    [X_pages_train] + [X_categoricals_train[col] for col in categorical_cols] + [X_numericals_train],
    y_train,
    batch_size=32,
    epochs=50,
    validation_split=0.2
)


loss, accuracy = model.evaluate([X_pages_test] + [X_categoricals_test[col] for col in categorical_cols] + [X_numericals_test], y_test)
print(f"Errore sui dati di test: {loss}")
print(f"Accuratezza sui dati di test: {accuracy}")
# Out:
# Encoding della pagina, nr di classi: 427
# 100%|██████████| 42365/42365 [00:25<00:00, 1636.76it/s]
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Page_Input (InputLayer)   │ (None, 1)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ UserName_Input            │ (None, 1)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Page_Embedding            │ (None, 1, 32)          │         13,664 │ Page_Input[0][0]       │
# │ (Embedding)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ UserName_Embedding        │ (None, 1, 10)          │            200 │ UserName_Input[0][0]   │
# │ (Embedding)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ LSTM (LSTM)               │ (None, 128)            │         82,432 │ Page_Embedding[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ UserName_Flatten          │ (None, 10)             │              0 │ UserName_Embedding[0]… │
# │ (Flatten)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Numerical_Input           │ (None, 0)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Concatenate (Concatenate) │ (None, 138)            │              0 │ LSTM[0][0],            │
# │                           │                        │                │ UserName_Flatten[0][0… │
# │                           │                        │                │ Numerical_Input[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Output (Dense)            │ (None, 427)            │         59,353 │ Concatenate[0][0]      │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 155,649 (608.00 KB)
#  Trainable params: 155,649 (608.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 4.5018 - sparse_categorical_accuracy: 0.1309 - val_loss: 3.7603 - val_sparse_categorical_accuracy: 0.1519
# Epoch 2/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 3.6628 - sparse_categorical_accuracy: 0.1710 - val_loss: 3.6214 - val_sparse_categorical_accuracy: 0.1786
# Epoch 3/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.5278 - sparse_categorical_accuracy: 0.1960 - val_loss: 3.5031 - val_sparse_categorical_accuracy: 0.2045
# Epoch 4/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 3.3925 - sparse_categorical_accuracy: 0.2196 - val_loss: 3.4540 - val_sparse_categorical_accuracy: 0.2056
# Epoch 5/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.3568 - sparse_categorical_accuracy: 0.2260 - val_loss: 3.4254 - val_sparse_categorical_accuracy: 0.2230
# Epoch 6/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 3.3013 - sparse_categorical_accuracy: 0.2323 - val_loss: 3.4027 - val_sparse_categorical_accuracy: 0.2288
# Epoch 7/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - loss: 3.2377 - sparse_categorical_accuracy: 0.2434 - val_loss: 3.3841 - val_sparse_categorical_accuracy: 0.2284
# Epoch 8/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 3.2376 - sparse_categorical_accuracy: 0.2430 - val_loss: 3.3788 - val_sparse_categorical_accuracy: 0.2344
# Epoch 9/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.2136 - sparse_categorical_accuracy: 0.2431 - val_loss: 3.3746 - val_sparse_categorical_accuracy: 0.2354
# Epoch 10/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.1959 - sparse_categorical_accuracy: 0.2463 - val_loss: 3.3708 - val_sparse_categorical_accuracy: 0.2326
# Epoch 11/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 3.1814 - sparse_categorical_accuracy: 0.2491 - val_loss: 3.3655 - val_sparse_categorical_accuracy: 0.2384
# Epoch 12/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.1526 - sparse_categorical_accuracy: 0.2524 - val_loss: 3.3676 - val_sparse_categorical_accuracy: 0.2362
# Epoch 13/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 3.1240 - sparse_categorical_accuracy: 0.2536 - val_loss: 3.3645 - val_sparse_categorical_accuracy: 0.2382
# Epoch 14/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 3.1002 - sparse_categorical_accuracy: 0.2602 - val_loss: 3.3713 - val_sparse_categorical_accuracy: 0.2348
# Epoch 15/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.1106 - sparse_categorical_accuracy: 0.2527 - val_loss: 3.3758 - val_sparse_categorical_accuracy: 0.2362
# Epoch 16/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.1155 - sparse_categorical_accuracy: 0.2522 - val_loss: 3.3791 - val_sparse_categorical_accuracy: 0.2363
# Epoch 17/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.0926 - sparse_categorical_accuracy: 0.2519 - val_loss: 3.3808 - val_sparse_categorical_accuracy: 0.2376
# Epoch 18/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.0954 - sparse_categorical_accuracy: 0.2531 - val_loss: 3.3862 - val_sparse_categorical_accuracy: 0.2353
# Epoch 19/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.0685 - sparse_categorical_accuracy: 0.2576 - val_loss: 3.3920 - val_sparse_categorical_accuracy: 0.2391
# Epoch 20/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.0607 - sparse_categorical_accuracy: 0.2625 - val_loss: 3.3950 - val_sparse_categorical_accuracy: 0.2345
# Epoch 21/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.0666 - sparse_categorical_accuracy: 0.2548 - val_loss: 3.3970 - val_sparse_categorical_accuracy: 0.2384
# Epoch 22/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.0449 - sparse_categorical_accuracy: 0.2566 - val_loss: 3.4030 - val_sparse_categorical_accuracy: 0.2379
# Epoch 23/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.0397 - sparse_categorical_accuracy: 0.2610 - val_loss: 3.4017 - val_sparse_categorical_accuracy: 0.2378
# Epoch 24/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.0352 - sparse_categorical_accuracy: 0.2552 - val_loss: 3.4083 - val_sparse_categorical_accuracy: 0.2387
# Epoch 25/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.0452 - sparse_categorical_accuracy: 0.2577 - val_loss: 3.4136 - val_sparse_categorical_accuracy: 0.2384
# Epoch 26/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 3.0149 - sparse_categorical_accuracy: 0.2605 - val_loss: 3.4211 - val_sparse_categorical_accuracy: 0.2376
# Epoch 27/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.0366 - sparse_categorical_accuracy: 0.2555 - val_loss: 3.4203 - val_sparse_categorical_accuracy: 0.2368
# Epoch 28/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 3.0242 - sparse_categorical_accuracy: 0.2559 - val_loss: 3.4254 - val_sparse_categorical_accuracy: 0.2379
# Epoch 29/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 3.0349 - sparse_categorical_accuracy: 0.2543 - val_loss: 3.4287 - val_sparse_categorical_accuracy: 0.2322
# Epoch 30/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 3.0286 - sparse_categorical_accuracy: 0.2588 - val_loss: 3.4315 - val_sparse_categorical_accuracy: 0.2366
# Epoch 31/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.9901 - sparse_categorical_accuracy: 0.2618 - val_loss: 3.4372 - val_sparse_categorical_accuracy: 0.2347
# Epoch 32/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.0228 - sparse_categorical_accuracy: 0.2535 - val_loss: 3.4410 - val_sparse_categorical_accuracy: 0.2376
# Epoch 33/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.9961 - sparse_categorical_accuracy: 0.2598 - val_loss: 3.4425 - val_sparse_categorical_accuracy: 0.2362
# Epoch 34/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.9784 - sparse_categorical_accuracy: 0.2580 - val_loss: 3.4480 - val_sparse_categorical_accuracy: 0.2376
# Epoch 35/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.0019 - sparse_categorical_accuracy: 0.2565 - val_loss: 3.4523 - val_sparse_categorical_accuracy: 0.2338
# Epoch 36/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 3.0077 - sparse_categorical_accuracy: 0.2542 - val_loss: 3.4546 - val_sparse_categorical_accuracy: 0.2351
# Epoch 37/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.0001 - sparse_categorical_accuracy: 0.2582 - val_loss: 3.4589 - val_sparse_categorical_accuracy: 0.2393
# Epoch 38/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 2.9765 - sparse_categorical_accuracy: 0.2599 - val_loss: 3.4598 - val_sparse_categorical_accuracy: 0.2343
# Epoch 39/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 2.9851 - sparse_categorical_accuracy: 0.2571 - val_loss: 3.4658 - val_sparse_categorical_accuracy: 0.2371
# Epoch 40/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 2.9722 - sparse_categorical_accuracy: 0.2599 - val_loss: 3.4689 - val_sparse_categorical_accuracy: 0.2371
# Epoch 41/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.9740 - sparse_categorical_accuracy: 0.2602 - val_loss: 3.4688 - val_sparse_categorical_accuracy: 0.2325
# Epoch 42/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 2.9800 - sparse_categorical_accuracy: 0.2584 - val_loss: 3.4740 - val_sparse_categorical_accuracy: 0.2338
# Epoch 43/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 2.9711 - sparse_categorical_accuracy: 0.2568 - val_loss: 3.4769 - val_sparse_categorical_accuracy: 0.2344
# Epoch 44/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 2.9645 - sparse_categorical_accuracy: 0.2641 - val_loss: 3.4861 - val_sparse_categorical_accuracy: 0.2310
# Epoch 45/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.9686 - sparse_categorical_accuracy: 0.2538 - val_loss: 3.4836 - val_sparse_categorical_accuracy: 0.2359
# Epoch 46/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.9674 - sparse_categorical_accuracy: 0.2582 - val_loss: 3.4882 - val_sparse_categorical_accuracy: 0.2385
# Epoch 47/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.9697 - sparse_categorical_accuracy: 0.2598 - val_loss: 3.4893 - val_sparse_categorical_accuracy: 0.2350
# Epoch 48/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 2.9596 - sparse_categorical_accuracy: 0.2584 - val_loss: 3.4949 - val_sparse_categorical_accuracy: 0.2353
# Epoch 49/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 2.9743 - sparse_categorical_accuracy: 0.2565 - val_loss: 3.5005 - val_sparse_categorical_accuracy: 0.2363
# Epoch 50/50
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 2.9464 - sparse_categorical_accuracy: 0.2627 - val_loss: 3.4990 - val_sparse_categorical_accuracy: 0.2354
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.4729 - sparse_categorical_accuracy: 0.2352
# Errore sui dati di test: 3.487558603286743
# Accuratezza sui dati di test: 0.24017466604709625

# %%
import numpy as np
from sklearn.metrics import classification_report

y_pred = model.predict([X_pages_test] + [X_categoricals_test[col] for col in categorical_cols] + [X_numericals_test])
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = y_test

print(classification_report(y_true_classes, y_pred_classes))
# Out:
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00         1
#            2       0.00      0.00      0.00         7
#            3       0.20      0.33      0.25       458
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#           10       0.21      0.15      0.17       252
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         1
#           15       0.00      0.00      0.00        48
#           17       0.00      0.00      0.00        20
#           18       0.00      0.00      0.00        46
#           20       0.11      0.06      0.08        16
#           21       0.11      0.29      0.15         7
#           24       0.00      0.00      0.00        17
#           25       1.00      0.50      0.67         2
#           27       0.00      0.00      0.00         1
#           28       0.00      0.00      0.00         1
#           29       0.00      0.00      0.
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
soglia_azioni = 0

# Ordino i dati per Utente e Timestamp
df_pair = df.sort_values(by=["UserName", "Apertura"])
df_pair = df_pair[df_pair['PageName'] != '/']

# Genero le coppie di transizioni consecutive
df_pair["NextPage"] = df_pair.groupby("UserName")["PageName"].shift(-1)
transitions = df_pair.dropna(subset=["NextPage"])

# Conteggio delle transizioni
transition_counts = transitions.groupby(["PageName", "NextPage"]).size().reset_index(name="Count")

# Filtra le transizioni con conteggio superiore a soglia_azioni
filtered_transitions = transition_counts[transition_counts["Count"] > soglia_azioni]

# Creazione della matrice di transizione
filtered_transition_matrix = pd.pivot_table(
    filtered_transitions,
    values="Count",
    index="PageName",
    columns="NextPage",
    fill_value=0
)

# %%
# Funzione per prevedere l'azione successiva
def predict_next_action(X_test, transition_matrix, y_test, y_pred):
    predictions = []
    cont=0
    for x in X_test:
        y_test_tmp = y_test[cont]
        y_true_page = sequence_encoding.inverse_transform([y_test_tmp])[0]
        y_pred_tmp = y_pred[cont]
        y_pred_page = sequence_encoding.inverse_transform([y_pred_tmp])[0]
        cont+=1
        # Estrai l'ultima pagina visitata dalla sequenza
        last_page_index = int(x[-1])  # Get the last element of the last timestep
        print(x)
        last_page = sequence_encoding.inverse_transform([last_page_index])[0]
        print(last_page)
        if last_page in transition_matrix.index:
            # Ottieni la riga corrispondente nella matrice
            next_page_probabilities = transition_matrix.loc[last_page]
            # Trova la pagina con il massimo conteggio
            # Handle the case where idxmax() returns an empty array
            predicted_page_name = next_page_probabilities.idxmax()
            if pd.isnull(predicted_page_name):
                # If idxmax() returns NaN, predict a placeholder or handle accordingly
                predicted_page = None # or any other placeholder value
            else:
                predicted_page = sequence_encoding.transform([predicted_page_name])[0]
                print(f'Pagina iniziale: {last_page_index} {last_page}')
                print(f'Pagina predetta: {predicted_page} {predicted_page_name}')
                print(f'Pagina corretta: {y_test_tmp} {y_true_page}')
                print(f'Pagina predetta lstm: {y_pred_tmp} {y_pred_page}')
                print(f'------------------------------------------------------')

        else:
            # Se la pagina non è nella matrice, prevedi un valore nullo o placeholder
            predicted_page = None
        predictions.append(predicted_page)
    return predictions
y_pred_labels = np.argmax(y_pred,axis=1)
y_pred_trans_matrix = predict_next_action(X_pages[test_idx], filtered_transition_matrix, y_test, y_pred_labels)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [419]
# /warehouses/warehouse-management/views-and-selection
# Pagina iniziale: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta: 416 /warehouses/warehouse-management/movements-research
# Pagina corretta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta lstm: 419 /warehouses/warehouse-management/views-and-selection
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 65 /business-partners/customers/:n/general-data
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [287]
# /price-lists
# Pagina iniziale: 287 /price-lists
# Pagina predetta: 288 /price-lists/:n/
# Pagina corretta: 287 /price-lists
# Pagina predetta lstm: 287 /price-lists
# ------------------------------------------------------
# [416]
# /warehouses/warehouse-management/movements-research
# Pagina iniziale: 416 /warehouses/warehouse-management/movements-research
# Pagina predetta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina corretta: 196 /customer-orders/packing-list-management/:n/
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [298]
# /products
# Pagina iniziale: 298 /products
# Pagina predetta: 305 /products/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 298 /products
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [286]
# /modules/:n/
# Pagina iniziale: 286 /modules/:n/
# Pagina predetta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina corretta: 15 /accounting/customer-document-header/new/general-data
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [10]
# /accounting/customer-document-header/:n/general-data
# Pagina iniziale: 10 /accounting/customer-document-header/:n/general-data
# Pagina predetta: 3 /accounting/customer-document-header
# Pagina corretta: 323 /products/copy/:n/general-data
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [71]
# /business-partners/customers/:n/management-data/settings
# Pagina iniziale: 71 /business-partners/customers/:n/management-data/settings
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 196 /customer-orders/packing-list-management/:n/
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [196]
# /customer-orders/packing-list-management/:n/
# Pagina iniziale: 196 /customer-orders/packing-list-management/:n/
# Pagina predetta: 197 /customer-orders/pick-list-situation
# Pagina corretta: 190 /customer-orders/customer-orders-crm/:n/general-data
# Pagina predetta lstm: 196 /customer-orders/packing-list-management/:n/
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [312]
# /products/:n/sale-pairings-v2
# Pagina iniziale: 312 /products/:n/sale-pairings-v2
# Pagina predetta: 298 /products
# Pagina corretta: 323 /products/copy/:n/general-data
# Pagina predetta lstm: 305 /products/:n/general-data
# ------------------------------------------------------
# [290]
# /price-lists/copy/:n/
# Pagina iniziale: 290 /price-lists/copy/:n/
# Pagina predetta: 287 /price-lists
# Pagina corretta: 305 /products/:n/general-data
# Pagina predetta lstm: 290 /price-lists/copy/:n/
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 165 /customer-orders/assignment-to-sales-order?nordine=13540
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [298]
# /products
# Pagina iniziale: 298 /products
# Pagina predetta: 305 /products/:n/general-data
# Pagina corretta: 305 /products/:n/general-data
# Pagina predetta lstm: 298 /products
# ------------------------------------------------------
# [197]
# /customer-orders/pick-list-situation
# Pagina iniziale: 197 /customer-orders/pick-list-situation
# Pagina predetta: 196 /customer-orders/packing-list-management/:n/
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 197 /customer-orders/pick-list-situation
# ------------------------------------------------------
# [419]
# /warehouses/warehouse-management/views-and-selection
# Pagina iniziale: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta: 416 /warehouses/warehouse-management/movements-research
# Pagina corretta: 196 /customer-orders/packing-list-management/:n/
# Pagina predetta lstm: 419 /warehouses/warehouse-management/views-and-selection
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 286 /modules/:n/
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [323]
# /products/copy/:n/general-data
# Pagina iniziale: 323 /products/copy/:n/general-data
# Pagina predetta: 328 /products/copy/:n/sale-pairings-v2
# Pagina corretta: 326 /products/copy/:n/images
# Pagina predetta lstm: 328 /products/copy/:n/sale-pairings-v2
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 3 /accounting/customer-document-header
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [375]
# /supplier-orders/supplier-invoice-header/:n/general-data
# Pagina iniziale: 375 /supplier-orders/supplier-invoice-header/:n/general-data
# Pagina predetta: 376 /supplier-orders/supplier-invoice-header/:n/incoming-check
# Pagina corretta: 375 /supplier-orders/supplier-invoice-header/:n/general-data
# Pagina predetta lstm: 375 /supplier-orders/supplier-invoice-header/:n/general-data
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [176]
# /customer-orders/auth-returns
# Pagina iniziale: 176 /customer-orders/auth-returns
# Pagina predetta: 178 /customer-orders/auth-returns/:n/general-data
# Pagina corretta: 178 /customer-orders/auth-returns/:n/general-data
# Pagina predetta lstm: 176 /customer-orders/auth-returns
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 197 /customer-orders/pick-list-situation
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [176]
# /customer-orders/auth-returns
# Pagina iniziale: 176 /customer-orders/auth-returns
# Pagina predetta: 178 /customer-orders/auth-returns/:n/general-data
# Pagina corretta: 183 /customer-orders/auth-to-credit-note
# Pagina predetta lstm: 176 /customer-orders/auth-returns
# ------------------------------------------------------
# [312]
# /products/:n/sale-pairings-v2
# Pagina iniziale: 312 /products/:n/sale-pairings-v2
# Pagina predetta: 298 /products
# Pagina corretta: 301 /products/:n/enablings/drops
# Pagina predetta lstm: 305 /products/:n/general-data
# ------------------------------------------------------
# [236]
# /general-data/head-counters
# Pagina iniziale: 236 /general-data/head-counters
# Pagina predetta: 237 /general-data/head-counters/:n/
# Pagina corretta: 236 /general-data/head-counters
# Pagina predetta lstm: 236 /general-data/head-counters
# ------------------------------------------------------
# [416]
# /warehouses/warehouse-management/movements-research
# Pagina iniziale: 416 /warehouses/warehouse-management/movements-research
# Pagina predetta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina corretta: 416 /warehouses/warehouse-management/movements-research
# Pagina predetta lstm: 419 /warehouses/warehouse-management/views-and-selection
# ------------------------------------------------------
# [419]
# /warehouses/warehouse-management/views-and-selection
# Pagina iniziale: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta: 416 /warehouses/warehouse-management/movements-research
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [65]
# /business-partners/customers/:n/general-data
# Pagina iniziale: 65 /business-partners/customers/:n/general-data
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 69 /business-partners/customers/:n/management-data/particularities
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [305]
# /products/:n/general-data
# Pagina iniziale: 305 /products/:n/general-data
# Pagina predetta: 298 /products
# Pagina corretta: 303 /products/:n/enablings/variants
# Pagina predetta lstm: 301 /products/:n/enablings/drops
# ------------------------------------------------------
# [69]
# /business-partners/customers/:n/management-data/particularities
# Pagina iniziale: 69 /business-partners/customers/:n/management-data/particularities
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 174 /customer-orders/auth-confirmation
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [71]
# /business-partners/customers/:n/management-data/settings
# Pagina iniziale: 71 /business-partners/customers/:n/management-data/settings
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 60 /business-partners/customers/:n/destinations/modal/business-partners/customers/new/general-data
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 359 /supplier-orders
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [337]
# /products/free-list
# Pagina iniziale: 337 /products/free-list
# Pagina predetta: 338 /products/free-list/:n/
# Pagina corretta: 416 /warehouses/warehouse-management/movements-research
# Pagina predetta lstm: 337 /products/free-list
# ------------------------------------------------------
# [197]
# /customer-orders/pick-list-situation
# Pagina iniziale: 197 /customer-orders/pick-list-situation
# Pagina predetta: 196 /customer-orders/packing-list-management/:n/
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 197 /customer-orders/pick-list-situation
# ------------------------------------------------------
# [65]
# /business-partners/customers/:n/general-data
# Pagina iniziale: 65 /business-partners/customers/:n/general-data
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [189]
# /customer-orders/customer-orders-crm
# Pagina iniziale: 189 /customer-orders/customer-orders-crm
# Pagina predetta: 190 /customer-orders/customer-orders-crm/:n/general-data
# Pagina corretta: 29 /accounting/massive-document-reprint
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [300]
# /products/:n/customer-references
# Pagina iniziale: 300 /products/:n/customer-references
# Pagina predetta: 309 /products/:n/images
# Pagina corretta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta lstm: 309 /products/:n/images
# ------------------------------------------------------
# [65]
# /business-partners/customers/:n/general-data
# Pagina iniziale: 65 /business-partners/customers/:n/general-data
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 71 /business-partners/customers/:n/management-data/settings
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [65]
# /business-partners/customers/:n/general-data
# Pagina iniziale: 65 /business-partners/customers/:n/general-data
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 55 /business-partners/customers/:n/contacts
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [288]
# /price-lists/:n/
# Pagina iniziale: 288 /price-lists/:n/
# Pagina predetta: 287 /price-lists
# Pagina corretta: 328 /products/copy/:n/sale-pairings-v2
# Pagina predetta lstm: 288 /price-lists/:n/
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 412 /warehouses/warehouse-management-materials/views-and-selection
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [374]
# /supplier-orders/supplier-invoice-header
# Pagina iniziale: 374 /supplier-orders/supplier-invoice-header
# Pagina predetta: 375 /supplier-orders/supplier-invoice-header/:n/general-data
# Pagina corretta: 375 /supplier-orders/supplier-invoice-header/:n/general-data
# Pagina predetta lstm: 374 /supplier-orders/supplier-invoice-header
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [180]
# /customer-orders/auth-returns/new/general-data
# Pagina iniziale: 180 /customer-orders/auth-returns/new/general-data
# Pagina predetta: 176 /customer-orders/auth-returns
# Pagina corretta: 174 /customer-orders/auth-confirmation
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [10]
# /accounting/customer-document-header/:n/general-data
# Pagina iniziale: 10 /accounting/customer-document-header/:n/general-data
# Pagina predetta: 3 /accounting/customer-document-header
# Pagina corretta: 10 /accounting/customer-document-header/:n/general-data
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [286]
# /modules/:n/
# Pagina iniziale: 286 /modules/:n/
# Pagina predetta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina corretta: 416 /warehouses/warehouse-management/movements-research
# Pagina predetta lstm: 286 /modules/:n/
# ------------------------------------------------------
# [312]
# /products/:n/sale-pairings-v2
# Pagina iniziale: 312 /products/:n/sale-pairings-v2
# Pagina predetta: 298 /products
# Pagina corretta: 301 /products/:n/enablings/drops
# Pagina predetta lstm: 305 /products/:n/general-data
# ------------------------------------------------------
# [197]
# /customer-orders/pick-list-situation
# Pagina iniziale: 197 /customer-orders/pick-list-situation
# Pagina predetta: 196 /customer-orders/packing-list-management/:n/
# Pagina corretta: 305 /products/:n/general-data
# Pagina predetta lstm: 197 /customer-orders/pick-list-situation
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [170]
# /customer-orders/assignment-to-sales-order?nordine=13718
# Pagina iniziale: 170 /customer-orders/assignment-to-sales-order?nordine=13718
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [197]
# /customer-orders/pick-list-situation
# Pagina iniziale: 197 /customer-orders/pick-list-situation
# Pagina predetta: 196 /customer-orders/packing-list-management/:n/
# Pagina corretta: 197 /customer-orders/pick-list-situation
# Pagina predetta lstm: 197 /customer-orders/pick-list-situation
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [91]
# /business-partners/sales-agents
# Pagina iniziale: 91 /business-partners/sales-agents
# Pagina predetta: 97 /business-partners/sales-agents/:n/general-data
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 98 /business-partners/sales-agents/:n/lines
# ------------------------------------------------------
# [298]
# /products
# Pagina iniziale: 298 /products
# Pagina predetta: 305 /products/:n/general-data
# Pagina corretta: 305 /products/:n/general-data
# Pagina predetta lstm: 298 /products
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 298 /products
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [298]
# /products
# Pagina iniziale: 298 /products
# Pagina predetta: 305 /products/:n/general-data
# Pagina corretta: 196 /customer-orders/packing-list-management/:n/
# Pagina predetta lstm: 298 /products
# ------------------------------------------------------
# [419]
# /warehouses/warehouse-management/views-and-selection
# Pagina iniziale: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta: 416 /warehouses/warehouse-management/movements-research
# Pagina corretta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta lstm: 419 /warehouses/warehouse-management/views-and-selection
# ------------------------------------------------------
# [197]
# /customer-orders/pick-list-situation
# Pagina iniziale: 197 /customer-orders/pick-list-situation
# Pagina predetta: 196 /customer-orders/packing-list-management/:n/
# Pagina corretta: 91 /business-partners/sales-agents
# Pagina predetta lstm: 197 /customer-orders/pick-list-situation
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 298 /products
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [65]
# /business-partners/customers/:n/general-data
# Pagina iniziale: 65 /business-partners/customers/:n/general-data
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [65]
# /business-partners/customers/:n/general-data
# Pagina iniziale: 65 /business-partners/customers/:n/general-data
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 3 /accounting/customer-document-header
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [305]
# /products/:n/general-data
# Pagina iniziale: 305 /products/:n/general-data
# Pagina predetta: 298 /products
# Pagina corretta: 298 /products
# Pagina predetta lstm: 303 /products/:n/enablings/variants
# ------------------------------------------------------
# [191]
# /customer-orders/lot-packing-situation
# Pagina iniziale: 191 /customer-orders/lot-packing-situation
# Pagina predetta: 163 /customer-orders/assignment-to-sales-order
# Pagina corretta: 197 /customer-orders/pick-list-situation
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [0]
# /accounting
# Pagina iniziale: 0 /accounting
# Pagina predetta: 3 /accounting/customer-document-header
# Pagina corretta: 65 /business-partners/customers/:n/general-data
# Pagina predetta lstm: 65 /business-partners/customers/:n/general-data
# ------------------------------------------------------
# [53]
# /business-partners/customers
# Pagina iniziale: 53 /business-partners/customers
# Pagina predetta: 65 /business-partners/customers/:n/general-data
# Pagina corretta: 65 /business-partners/customers/:n/general-data
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [53]
# /business-partners/customers
# Pagina iniziale: 53 /business-partners/customers
# Pagina predetta: 65 /business-partners/customers/:n/general-data
# Pagina corretta: 286 /modules/:n/
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [406]
# /warehouses/pack-unpack-management
# Pagina iniziale: 406 /warehouses/pack-unpack-management
# Pagina predetta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [305]
# /products/:n/general-data
# Pagina iniziale: 305 /products/:n/general-data
# Pagina predetta: 298 /products
# Pagina corretta: 299 /products/:n/barcode
# Pagina predetta lstm: 298 /products
# ------------------------------------------------------
# [419]
# /warehouses/warehouse-management/views-and-selection
# Pagina iniziale: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta: 416 /warehouses/warehouse-management/movements-research
# Pagina corretta: 29 /accounting/massive-document-reprint
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [237]
# /general-data/head-counters/:n/
# Pagina iniziale: 237 /general-data/head-counters/:n/
# Pagina predetta: 236 /general-data/head-counters
# Pagina corretta: 237 /general-data/head-counters/:n/
# Pagina predetta lstm: 237 /general-data/head-counters/:n/
# ------------------------------------------------------
# [419]
# /warehouses/warehouse-management/views-and-selection
# Pagina iniziale: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta: 416 /warehouses/warehouse-management/movements-research
# Pagina corretta: 237 /general-data/head-counters/:n/
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [305]
# /products/:n/general-data
# Pagina iniziale: 305 /products/:n/general-data
# Pagina predetta: 298 /products
# Pagina corretta: 305 /products/:n/general-data
# Pagina predetta lstm: 303 /products/:n/enablings/variants
# ------------------------------------------------------
# [410]
# /warehouses/warehouse-management-materials/movements-research
# Pagina iniziale: 410 /warehouses/warehouse-management-materials/movements-research
# Pagina predetta: 409 /warehouses/warehouse-management-materials/move-from-stock
# Pagina corretta: 15 /accounting/customer-document-header/new/general-data
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [197]
# /customer-orders/pick-list-situation
# Pagina iniziale: 197 /customer-orders/pick-list-situation
# Pagina predetta: 196 /customer-orders/packing-list-management/:n/
# Pagina corretta: 197 /customer-orders/pick-list-situation
# Pagina predetta lstm: 197 /customer-orders/pick-list-situation
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [175]
# /customer-orders/auth-receiving
# Pagina iniziale: 175 /customer-orders/auth-receiving
# Pagina predetta: 183 /customer-orders/auth-to-credit-note
# Pagina corretta: 10 /accounting/customer-document-header/:n/general-data
# Pagina predetta lstm: 10 /accounting/customer-document-header/:n/general-data
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 3 /accounting/customer-document-header
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [419]
# /warehouses/warehouse-management/views-and-selection
# Pagina iniziale: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta: 416 /warehouses/warehouse-management/movements-research
# Pagina corretta: 298 /products
# Pagina predetta lstm: 419 /warehouses/warehouse-management/views-and-selection
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 412 /warehouses/warehouse-management-materials/views-and-selection
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [298]
# /products
# Pagina iniziale: 298 /products
# Pagina predetta: 305 /products/:n/general-data
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 298 /products
# ------------------------------------------------------
# [65]
# /business-partners/customers/:n/general-data
# Pagina iniziale: 65 /business-partners/customers/:n/general-data
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [65]
# /business-partners/customers/:n/general-data
# Pagina iniziale: 65 /business-partners/customers/:n/general-data
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 65 /business-partners/customers/:n/general-data
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [316]
# /products/config-barcode/:n/
# Pagina iniziale: 316 /products/config-barcode/:n/
# Pagina predetta: 315 /products/config-barcode
# Pagina corretta: 196 /customer-orders/packing-list-management/:n/
# Pagina predetta lstm: 315 /products/config-barcode
# ------------------------------------------------------
# [15]
# /accounting/customer-document-header/new/general-data
# Pagina iniziale: 15 /accounting/customer-document-header/new/general-data
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 275 /general-data/warehouse-products/:n/
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [189]
# /customer-orders/customer-orders-crm
# Pagina iniziale: 189 /customer-orders/customer-orders-crm
# Pagina predetta: 190 /customer-orders/customer-orders-crm/:n/general-data
# Pagina corretta: 416 /warehouses/warehouse-management/movements-research
# Pagina predetta lstm: 189 /customer-orders/customer-orders-crm
# ------------------------------------------------------
# [361]
# /supplier-orders/:n/general-data
# Pagina iniziale: 361 /supplier-orders/:n/general-data
# Pagina predetta: 363 /supplier-orders/:n/rows
# Pagina corretta: 197 /customer-orders/pick-list-situation
# Pagina predetta lstm: 361 /supplier-orders/:n/general-data
# ------------------------------------------------------
# [176]
# /customer-orders/auth-returns
# Pagina iniziale: 176 /customer-orders/auth-returns
# Pagina predetta: 178 /customer-orders/auth-returns/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 176 /customer-orders/auth-returns
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 236 /general-data/head-counters
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [402]
# /warehouses
# Pagina iniziale: 402 /warehouses
# Pagina predetta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina corretta: 416 /warehouses/warehouse-management/movements-research
# Pagina predetta lstm: 419 /warehouses/warehouse-management/views-and-selection
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 386 /supplier-orders/supplier-order-materials
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [328]
# /products/copy/:n/sale-pairings-v2
# Pagina iniziale: 328 /products/copy/:n/sale-pairings-v2
# Pagina predetta: 326 /products/copy/:n/images
# Pagina corretta: 298 /products
# Pagina predetta lstm: 298 /products
# ------------------------------------------------------
# [53]
# /business-partners/customers
# Pagina iniziale: 53 /business-partners/customers
# Pagina predetta: 65 /business-partners/customers/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [176]
# /customer-orders/auth-returns
# Pagina iniziale: 176 /customer-orders/auth-returns
# Pagina predetta: 178 /customer-orders/auth-returns/:n/general-data
# Pagina corretta: 392 /supplier-orders/supplier-order-materials/new/general-data
# Pagina predetta lstm: 176 /customer-orders/auth-returns
# ------------------------------------------------------
# [196]
# /customer-orders/packing-list-management/:n/
# Pagina iniziale: 196 /customer-orders/packing-list-management/:n/
# Pagina predetta: 197 /customer-orders/pick-list-situation
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 196 /customer-orders/packing-list-management/:n/
# ------------------------------------------------------
# [290]
# /price-lists/copy/:n/
# Pagina iniziale: 290 /price-lists/copy/:n/
# Pagina predetta: 287 /price-lists
# Pagina corretta: 290 /price-lists/copy/:n/
# Pagina predetta lstm: 290 /price-lists/copy/:n/
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 3 /accounting/customer-document-header
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [18]
# /accounting/customer-documents-from-customer-orders
# Pagina iniziale: 18 /accounting/customer-documents-from-customer-orders
# Pagina predetta: 3 /accounting/customer-document-header
# Pagina corretta: 381 /supplier-orders/supplier-invoice-header/new/general-data
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [178]
# /customer-orders/auth-returns/:n/general-data
# Pagina iniziale: 178 /customer-orders/auth-returns/:n/general-data
# Pagina predetta: 176 /customer-orders/auth-returns
# Pagina corretta: 20 /accounting/document-types
# Pagina predetta lstm: 176 /customer-orders/auth-returns
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 381 /supplier-orders/supplier-invoice-header/new/general-data
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [303]
# /products/:n/enablings/variants
# Pagina iniziale: 303 /products/:n/enablings/variants
# Pagina predetta: 301 /products/:n/enablings/drops
# Pagina corretta: 312 /products/:n/sale-pairings-v2
# Pagina predetta lstm: 312 /products/:n/sale-pairings-v2
# ------------------------------------------------------
# [197]
# /customer-orders/pick-list-situation
# Pagina iniziale: 197 /customer-orders/pick-list-situation
# Pagina predetta: 196 /customer-orders/packing-list-management/:n/
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 197 /customer-orders/pick-list-situation
# ------------------------------------------------------
# [290]
# /price-lists/copy/:n/
# Pagina iniziale: 290 /price-lists/copy/:n/
# Pagina predetta: 287 /price-lists
# Pagina corretta: 290 /price-lists/copy/:n/
# Pagina predetta lstm: 290 /price-lists/copy/:n/
# ------------------------------------------------------
# [321]
# /products/copy/:n/enablings/drops
# Pagina iniziale: 321 /products/copy/:n/enablings/drops
# Pagina predetta: 328 /products/copy/:n/sale-pairings-v2
# Pagina corretta: 328 /products/copy/:n/sale-pairings-v2
# Pagina predetta lstm: 328 /products/copy/:n/sale-pairings-v2
# ------------------------------------------------------
# [305]
# /products/:n/general-data
# Pagina iniziale: 305 /products/:n/general-data
# Pagina predetta: 298 /products
# Pagina corretta: 305 /products/:n/general-data
# Pagina predetta lstm: 305 /products/:n/general-data
# ------------------------------------------------------
# [359]
# /supplier-orders
# Pagina iniziale: 359 /supplier-orders
# Pagina predetta: 361 /supplier-orders/:n/general-data
# Pagina corretta: 363 /supplier-orders/:n/rows
# Pagina predetta lstm: 363 /supplier-orders/:n/rows
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [321]
# /products/copy/:n/enablings/drops
# Pagina iniziale: 321 /products/copy/:n/enablings/drops
# Pagina predetta: 328 /products/copy/:n/sale-pairings-v2
# Pagina corretta: 328 /products/copy/:n/sale-pairings-v2
# Pagina predetta lstm: 328 /products/copy/:n/sale-pairings-v2
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 386 /supplier-orders/supplier-order-materials
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [249]
# /general-data/payments/update-accounting/:n/
# Pagina iniziale: 249 /general-data/payments/update-accounting/:n/
# Pagina predetta: 248 /general-data/payments
# Pagina corretta: 298 /products
# Pagina predetta lstm: 312 /products/:n/sale-pairings-v2
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 305 /products/:n/general-data
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [303]
# /products/:n/enablings/variants
# Pagina iniziale: 303 /products/:n/enablings/variants
# Pagina predetta: 301 /products/:n/enablings/drops
# Pagina corretta: 312 /products/:n/sale-pairings-v2
# Pagina predetta lstm: 312 /products/:n/sale-pairings-v2
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 371 /supplier-orders/preload-asn
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [196]
# /customer-orders/packing-list-management/:n/
# Pagina iniziale: 196 /customer-orders/packing-list-management/:n/
# Pagina predetta: 197 /customer-orders/pick-list-situation
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 196 /customer-orders/packing-list-management/:n/
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 174 /customer-orders/auth-confirmation
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [190]
# /customer-orders/customer-orders-crm/:n/general-data
# Pagina iniziale: 190 /customer-orders/customer-orders-crm/:n/general-data
# Pagina predetta: 189 /customer-orders/customer-orders-crm
# Pagina corretta: 190 /customer-orders/customer-orders-crm/:n/general-data
# Pagina predetta lstm: 190 /customer-orders/customer-orders-crm/:n/general-data
# ------------------------------------------------------
# [65]
# /business-partners/customers/:n/general-data
# Pagina iniziale: 65 /business-partners/customers/:n/general-data
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 65 /business-partners/customers/:n/general-data
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [197]
# /customer-orders/pick-list-situation
# Pagina iniziale: 197 /customer-orders/pick-list-situation
# Pagina predetta: 196 /customer-orders/packing-list-management/:n/
# Pagina corretta: 3 /accounting/customer-document-header
# Pagina predetta lstm: 197 /customer-orders/pick-list-situation
# ------------------------------------------------------
# [303]
# /products/:n/enablings/variants
# Pagina iniziale: 303 /products/:n/enablings/variants
# Pagina predetta: 301 /products/:n/enablings/drops
# Pagina corretta: 312 /products/:n/sale-pairings-v2
# Pagina predetta lstm: 312 /products/:n/sale-pairings-v2
# ------------------------------------------------------
# [80]
# /business-partners/customers/copy/:n/electronic-invoicing
# Pagina iniziale: 80 /business-partners/customers/copy/:n/electronic-invoicing
# Pagina predetta: 81 /business-partners/customers/copy/:n/expenses
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 88 /business-partners/customers/copy/:n/management-data/settings
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [194]
# /customer-orders/new/general-data
# Pagina iniziale: 194 /customer-orders/new/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 3 /accounting/customer-document-header
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 196 /customer-orders/packing-list-management/:n/
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [10]
# /accounting/customer-document-header/:n/general-data
# Pagina iniziale: 10 /accounting/customer-document-header/:n/general-data
# Pagina predetta: 3 /accounting/customer-document-header
# Pagina corretta: 3 /accounting/customer-document-header
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [337]
# /products/free-list
# Pagina iniziale: 337 /products/free-list
# Pagina predetta: 338 /products/free-list/:n/
# Pagina corretta: 337 /products/free-list
# Pagina predetta lstm: 337 /products/free-list
# ------------------------------------------------------
# [30]
# /accounting/supplier-document
# Pagina iniziale: 30 /accounting/supplier-document
# Pagina predetta: 31 /accounting/supplier-document/:n/general-data
# Pagina corretta: 30 /accounting/supplier-document
# Pagina predetta lstm: 30 /accounting/supplier-document
# ------------------------------------------------------
# [196]
# /customer-orders/packing-list-management/:n/
# Pagina iniziale: 196 /customer-orders/packing-list-management/:n/
# Pagina predetta: 197 /customer-orders/pick-list-situation
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 196 /customer-orders/packing-list-management/:n/
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [65]
# /business-partners/customers/:n/general-data
# Pagina iniziale: 65 /business-partners/customers/:n/general-data
# Pagina predetta: 53 /business-partners/customers
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [288]
# /price-lists/:n/
# Pagina iniziale: 288 /price-lists/:n/
# Pagina predetta: 287 /price-lists
# Pagina corretta: 288 /price-lists/:n/
# Pagina predetta lstm: 288 /price-lists/:n/
# ------------------------------------------------------
# [180]
# /customer-orders/auth-returns/new/general-data
# Pagina iniziale: 180 /customer-orders/auth-returns/new/general-data
# Pagina predetta: 176 /customer-orders/auth-returns
# Pagina corretta: 309 /products/:n/images
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [406]
# /warehouses/pack-unpack-management
# Pagina iniziale: 406 /warehouses/pack-unpack-management
# Pagina predetta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 419 /warehouses/warehouse-management/views-and-selection
# ------------------------------------------------------
# [287]
# /price-lists
# Pagina iniziale: 287 /price-lists
# Pagina predetta: 288 /price-lists/:n/
# Pagina corretta: 287 /price-lists
# Pagina predetta lstm: 287 /price-lists
# ------------------------------------------------------
# [194]
# /customer-orders/new/general-data
# Pagina iniziale: 194 /customer-orders/new/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [197]
# ...
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [419]
# /warehouses/warehouse-management/views-and-selection
# Pagina iniziale: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta: 416 /warehouses/warehouse-management/movements-research
# Pagina corretta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [298]
# /products
# Pagina iniziale: 298 /products
# Pagina predetta: 305 /products/:n/general-data
# Pagina corretta: 361 /supplier-orders/:n/general-data
# Pagina predetta lstm: 298 /products
# ------------------------------------------------------
# [419]
# /warehouses/warehouse-management/views-and-selection
# Pagina iniziale: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta: 416 /warehouses/warehouse-management/movements-research
# Pagina corretta: 298 /products
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [320]
# /products/copy/:n/customer-references
# Pagina iniziale: 320 /products/copy/:n/customer-references
# Pagina predetta: 326 /products/copy/:n/images
# Pagina corretta: 298 /products
# Pagina predetta lstm: 298 /products
# ------------------------------------------------------
# [303]
# /products/:n/enablings/variants
# Pagina iniziale: 303 /products/:n/enablings/variants
# Pagina predetta: 301 /products/:n/enablings/drops
# Pagina corretta: 312 /products/:n/sale-pairings-v2
# Pagina predetta lstm: 312 /products/:n/sale-pairings-v2
# ------------------------------------------------------
# [196]
# /customer-orders/packing-list-management/:n/
# Pagina iniziale: 196 /customer-orders/packing-list-management/:n/
# Pagina predetta: 197 /customer-orders/pick-list-situation
# Pagina corretta: 197 /customer-orders/pick-list-situation
# Pagina predetta lstm: 196 /customer-orders/packing-list-management/:n/
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 237 /general-data/head-counters/:n/
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [53]
# /business-partners/customers
# Pagina iniziale: 53 /business-partners/customers
# Pagina predetta: 65 /business-partners/customers/:n/general-data
# Pagina corretta: 54 /business-partners/customers/:n/accounting-data
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [392]
# /supplier-orders/supplier-order-materials/new/general-data
# Pagina iniziale: 392 /supplier-orders/supplier-order-materials/new/general-data
# Pagina predetta: 388 /supplier-orders/supplier-order-materials/:n/general-data
# Pagina corretta: 388 /supplier-orders/supplier-order-materials/:n/general-data
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 286 /modules/:n/
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [20]
# /accounting/document-types
# Pagina iniziale: 20 /accounting/document-types
# Pagina predetta: 21 /accounting/document-types/:n/general-data
# Pagina corretta: 298 /products
# Pagina predetta lstm: 21 /accounting/document-types/:n/general-data
# ------------------------------------------------------
# [97]
# /business-partners/sales-agents/:n/general-data
# Pagina iniziale: 97 /business-partners/sales-agents/:n/general-data
# Pagina predetta: 98 /business-partners/sales-agents/:n/lines
# Pagina corretta: 92 /business-partners/sales-agents/:n/categories
# Pagina predetta lstm: 102 /business-partners/sales-agents/:n/price-lists
# ------------------------------------------------------
# [290]
# /price-lists/copy/:n/
# Pagina iniziale: 290 /price-lists/copy/:n/
# Pagina predetta: 287 /price-lists
# Pagina corretta: 305 /products/:n/general-data
# Pagina predetta lstm: 290 /price-lists/copy/:n/
# ------------------------------------------------------
# [29]
# /accounting/massive-document-reprint
# Pagina iniziale: 29 /accounting/massive-document-reprint
# Pagina predetta: 3 /accounting/customer-document-header
# Pagina corretta: 176 /customer-orders/auth-returns
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [286]
# /modules/:n/
# Pagina iniziale: 286 /modules/:n/
# Pagina predetta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina corretta: 3 /accounting/customer-document-header
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [303]
# /products/:n/enablings/variants
# Pagina iniziale: 303 /products/:n/enablings/variants
# Pagina predetta: 301 /products/:n/enablings/drops
# Pagina corretta: 3 /accounting/customer-document-header
# Pagina predetta lstm: 302 /products/:n/enablings/stature
# ------------------------------------------------------
# [53]
# /business-partners/customers
# Pagina iniziale: 53 /business-partners/customers
# Pagina predetta: 65 /business-partners/customers/:n/general-data
# Pagina corretta: 65 /business-partners/customers/:n/general-data
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [21]
# /accounting/document-types/:n/general-data
# Pagina iniziale: 21 /accounting/document-types/:n/general-data
# Pagina predetta: 20 /accounting/document-types
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 20 /accounting/document-types
# ------------------------------------------------------
# [176]
# /customer-orders/auth-returns
# Pagina iniziale: 176 /customer-orders/auth-returns
# Pagina predetta: 178 /customer-orders/auth-returns/:n/general-data
# Pagina corretta: 174 /customer-orders/auth-confirmation
# Pagina predetta lstm: 176 /customer-orders/auth-returns
# ------------------------------------------------------
# [418]
# /warehouses/warehouse-management/stock-management
# Pagina iniziale: 418 /warehouses/warehouse-management/stock-management
# Pagina predetta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina corretta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [176]
# /customer-orders/auth-returns
# Pagina iniziale: 176 /customer-orders/auth-returns
# Pagina predetta: 178 /customer-orders/auth-returns/:n/general-data
# Pagina corretta: 176 /customer-orders/auth-returns
# Pagina predetta lstm: 176 /customer-orders/auth-returns
# ------------------------------------------------------
# [305]
# /products/:n/general-data
# Pagina iniziale: 305 /products/:n/general-data
# Pagina predetta: 298 /products
# Pagina corretta: 298 /products
# Pagina predetta lstm: 301 /products/:n/enablings/drops
# ------------------------------------------------------
# [361]
# /supplier-orders/:n/general-data
# Pagina iniziale: 361 /supplier-orders/:n/general-data
# Pagina predetta: 363 /supplier-orders/:n/rows
# Pagina corretta: 361 /supplier-orders/:n/general-data
# Pagina predetta lstm: 361 /supplier-orders/:n/general-data
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [416]
# /warehouses/warehouse-management/movements-research
# Pagina iniziale: 416 /warehouses/warehouse-management/movements-research
# Pagina predetta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina corretta: 419 /warehouses/warehouse-management/views-and-selection
# Pagina predetta lstm: 419 /warehouses/warehouse-management/views-and-selection
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 17 /accounting/customer-documents-accounting
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 381 /supplier-orders/supplier-invoice-header/new/general-data
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [3]
# /accounting/customer-document-header
# Pagina iniziale: 3 /accounting/customer-document-header
# Pagina predetta: 10 /accounting/customer-document-header/:n/general-data
# Pagina corretta: 175 /customer-orders/auth-receiving
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------
# [409]
# /warehouses/warehouse-management-materials/move-from-stock
# Pagina iniziale: 409 /warehouses/warehouse-management-materials/move-from-stock
# Pagina predetta: 410 /warehouses/warehouse-management-materials/movements-research
# Pagina corretta: 180 /customer-orders/auth-returns/new/general-data
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [236]
# /general-data/head-counters
# Pagina iniziale: 236 /general-data/head-counters
# Pagina predetta: 237 /general-data/head-counters/:n/
# Pagina corretta: 236 /general-data/head-counters
# Pagina predetta lstm: 236 /general-data/head-counters
# ------------------------------------------------------
# [381]
# /supplier-orders/supplier-invoice-header/new/general-data
# Pagina iniziale: 381 /supplier-orders/supplier-invoice-header/new/general-data
# Pagina predetta: 382 /supplier-orders/supplier-invoice-header/new/incoming-check
# Pagina corretta: 381 /supplier-orders/supplier-invoice-header/new/general-data
# Pagina predetta lstm: 381 /supplier-orders/supplier-invoice-header/new/general-data
# ------------------------------------------------------
# [298]
# /products
# Pagina iniziale: 298 /products
# Pagina predetta: 305 /products/:n/general-data
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 298 /products
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 189 /customer-orders/customer-orders-crm
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [197]
# /customer-orders/pick-list-situation
# Pagina iniziale: 197 /customer-orders/pick-list-situation
# Pagina predetta: 196 /customer-orders/packing-list-management/:n/
# Pagina corretta: 10 /accounting/customer-document-header/:n/general-data
# Pagina predetta lstm: 197 /customer-orders/pick-list-situation
# ------------------------------------------------------
# [312]
# /products/:n/sale-pairings-v2
# Pagina iniziale: 312 /products/:n/sale-pairings-v2
# Pagina predetta: 298 /products
# Pagina corretta: 312 /products/:n/sale-pairings-v2
# Pagina predetta lstm: 298 /products
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 156 /customer-orders
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [323]
# /products/copy/:n/general-data
# Pagina iniziale: 323 /products/copy/:n/general-data
# Pagina predetta: 328 /products/copy/:n/sale-pairings-v2
# Pagina corretta: 326 /products/copy/:n/images
# Pagina predetta lstm: 328 /products/copy/:n/sale-pairings-v2
# ------------------------------------------------------
# [312]
# /products/:n/sale-pairings-v2
# Pagina iniziale: 312 /products/:n/sale-pairings-v2
# Pagina predetta: 298 /products
# Pagina corretta: 298 /products
# Pagina predetta lstm: 305 /products/:n/general-data
# ------------------------------------------------------
# [159]
# /customer-orders/:n/general-data
# Pagina iniziale: 159 /customer-orders/:n/general-data
# Pagina predetta: 156 /customer-orders
# Pagina corretta: 128 /business-partners/suppliers/new/accounting-data
# Pagina predetta lstm: 159 /customer-orders/:n/general-data
# ------------------------------------------------------
# [53]
# /business-partners/customers
# Pagina iniziale: 53 /business-partners/customers
# Pagina predetta: 65 /business-partners/customers/:n/general-data
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [63]
# /business-partners/customers/:n/electronic-invoicing
# Pagina iniziale: 63 /business-partners/customers/:n/electronic-invoicing
# Pagina predetta: 71 /business-partners/customers/:n/management-data/settings
# Pagina corretta: 53 /business-partners/customers
# Pagina predetta lstm: 53 /business-partners/customers
# ------------------------------------------------------
# [386]
# /supplier-orders/supplier-order-materials
# Pagina iniziale: 386 /supplier-orders/supplier-order-materials
# Pagina predetta: 388 /supplier-orders/supplier-order-materials/:n/general-data
# Pagina corretta: 388 /supplier-orders/supplier-order-materials/:n/general-data
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [197]
# /customer-orders/pick-list-situation
# Pagina iniziale: 197 /customer-orders/pick-list-situation
# Pagina predetta: 196 /customer-orders/packing-list-management/:n/
# Pagina corretta: 305 /products/:n/general-data
# Pagina predetta lstm: 197 /customer-orders/pick-list-situation
# ------------------------------------------------------
# [156]
# /customer-orders
# Pagina iniziale: 156 /customer-orders
# Pagina predetta: 159 /customer-orders/:n/general-data
# Pagina corretta: 194 /customer-orders/new/general-data
# Pagina predetta lstm: 156 /customer-orders
# ------------------------------------------------------
# [328]
# /products/copy/:n/sale-pairings-v2
# Pagina iniziale: 328 /products/copy/:n/sale-pairings-v2
# Pagina predetta: 326 /products/copy/:n/images
# Pagina corretta: 200 /customer-orders/shipping-list-edit
# Pagina predetta lstm: 298 /products
# ------------------------------------------------------
# [176]
# /customer-orders/auth-returns
# Pagina iniziale: 176 /customer-orders/auth-returns
# Pagina predetta: 178 /customer-orders/auth-returns/:n/general-data
# Pagina corretta: 176 /customer-orders/auth-returns
# Pagina predetta lstm: 176 /customer-orders/auth-returns
# ------------------------------------------------------
# [410]
# /warehouses/warehouse-management-materials/movements-research
# Pagina iniziale: 410 /warehouses/warehouse-management-materials/movements-research
# Pagina predetta: 409 /warehouses/warehouse-management-materials/move-from-stock
# Pagina corretta: 159 /customer-orders/:n/general-data
# Pagina predetta lstm: 3 /accounting/customer-document-header
# ------------------------------------------------------

# %%
# y_true_correct = []
# for y in y_test:
#     y_test_tmp = int(y_encoder.inverse_transform(np.expand_dims(y, 0))[0][0])
#     y_true_correct.append(y_test_tmp)

# %%
print(classification_report(y_test, y_pred_trans_matrix))

########### FINE ###################
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00         1
#            2       0.00      0.00      0.00         7
#            3       0.15      0.16      0.15       458
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#           10       0.08      0.17      0.11       252
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         1
#           15       0.00      0.00      0.00        48
#           17       0.00      0.00      0.00        20
#           18       0.00      0.00      0.00        46
#           20       0.11      0.06      0.08        16
#           21       0.11      0.29      0.15         7
#           24       0.00      0.00      0.00        17
#           25       0.00      0.00      0.00         2
#           27       0.00      0.00      0.00         1
#           28       0.00      0.00      0.00         1
#           29       0.00      0.00      0.00        41
#           30       0.00      0.00      0.00        27
#           31       0.09      0.21      0.12        14
#           32       0.00      0.00      0.00         5
#           34       0.00      0.00      0.00         1
#           37       0.00      0.00      0.00